# %%
# 1. Import pyafmreader loadfile and matplotlib
from pyfmreader import loadfile
import matplotlib.pyplot as plt
import os

# Get documentation about loadfile function
help(loadfile)
# Out:
# Help on function loadfile in module pyfmreader.pyfmreader:
#
# loadfile(filepath)
#     Load AFM file.
#
#     Supported formats:
#         - JPK --> .jpk-force, .jpk-force-map, .jpk-qi-data
#         - JPK h5 files --> .h5-jpk,(moder Nano Wizard5)
#         - NANOSCOPE --> .spm, .pfc, .00X
#         - PS-NEX --> .tdms
#         - HS-3 --> .tdms
#         - IBW --> .ibw (Asylum files)
#         - ARDF --> .ARDF (Asylum force maps)
#         - UFF --> .uff
#         - JPK Thermal --> .tnd
#
#             Parameters:
#                     filepath (str): Path to the file.
#
#             Returns:
#                     If JPK, NANOSCOPE OR UFF:
#                         UFF (uff.UFF): Universal File Format object containing loaded data.
#                     If JPK Thermal:
#                         Amplitude (m^2/V) (np.array),
#                         Frequencies (Hz) (np.array),
#                         Fit-Data (m^2/V) (np.array),
#                         Parameters (dict)

# %%
# 2. Load one of the test files
NANOSC_PFC_PATH = '/Users/evillz/Github/PyFMlab_DyNaMo/PyFMReader_DyNaMo/tests/testfiles/qi-data-2018.11.22-17.54.05.153.jpk-qi-data'

NANOSC_PFC_FILE = loadfile(NANOSC_PFC_PATH)

type(NANOSC_PFC_FILE)
NANOSC_PFC_FILE.isFV
# Out:
# True

# %%
# 3. Get file metadata
metadata = NANOSC_PFC_FILE.filemetadata

for key, item in metadata.items():
    print(f"{key} : {item}\n")
# Out:
# file_path : /Users/evillz/Github/PyFMlab_DyNaMo/PyFMReader_DyNaMo/tests/testfiles/qi-data-2018.11.22-17.54.05.153.jpk-qi-data
#
# Entry_filename : qi-data-2018.11.22-17.54.05.153.jpk-qi-data
#
# file_size_bytes : 6532220
#
# file_type : jpk-qi-data
#
# UFF_code : _1_2_3_4_5
#
# Entry_UFF_version : 0
#
# file_id : 17.54.05.153
#
# force_volume : 1
#
# Experimental_instrument : JPK00733
#
# JPK_file_format_version : 2.0
#
# JPK_software_version : 6.1.111
#
# retracted_delay : 0.0
#
# extended_delay : 0.0
#
# Entry_date : 2018-11-22 17\:54\:05.153 +0100
#
# scan_angle : 0.0
#
# num_x_pixels : 12
#
# num_y_pixels : 12
#
# scan_size_x : 3e-05
#
# scan_size_y : 3e-05
#
# z_closed_loop : false
#
# Recording_Z_close_loop_on : Off
#
# Entry_tot_nb_curve : 144
#
# extend_pause_duration : 0.0
#
# relative_z_start : 0.0
#
# relative_z_end : 0.0
#
# relative_ramp_size : 0.0
#
# force_setpoint : 3.894240223996698
#
# nbr_channels : 10
#
# defl_sens_nmbyV : 21.67
#
# spring_const_Nbym : 0.0237
#
# channel_properties : {'head-height': {'channel_id': 0, 'encoder_type': 'signedinteger', 'encoder_offet_key': 50.00000001164153, 'encoder_multiplier_key': 2.3283064370807974e-08, 'base': 'volts', 'base_defined': False, 'absolute_defined': False, 'capSensHeight_abs_offset': 0.0, 'capSensHeight_abs_mult': 1000000000.0, 'nominal_defined': True, 'capSensHeight_nom_offset': 6.5e-06, 'capSensHeight_nom_mult': -6.5e-08}, 'height': {'channel_id': 1, 'encoder_type': 'signedinteger', 'encoder_offet_key': 50.00000001164153, 'encoder_multiplier_key': 2.3283064370807974e-08, 'base': 'volts', 'base_defined': False, 'absolute_defined': False, 'capSensHeight_abs_offset': 0.0, 'capSensHeight_abs_mult': 1000000000.0, 'nominal_defined': True, 'capSensHeight_nom_offset': 6.5e-06, 'capSensHeight_nom_mult': -6.5e-08}, 'vDeflection': {'channel_id': 2, 'encoder_type': 'signedinteger', 'encoder_offet_key': 5.520459503146758e-05, 'encoder_multiplier_key': 5.58439003852485e-09, 'base': 'volts', 'base_defined': False, 'distance_defined': True, 'deflection_distance_offset': 0.0, 'deflection_distance_multiplier': 21.67, 'force_defined': True, 'deflection_force_offset': 0.0, 'deflection_force_multiplier': 0.0237}, 'hDeflection': {'channel_id': 3, 'encoder_type': 'signedinteger', 'encoder_offet_key': 0.00017964596394576238, 'encoder_multiplier_key': 5.590015835859922e-09, 'base': 'volts', 'base_defined': False, 'distance_defined': False, 'deflection_distance_offset': 0.0, 'deflection_distance_multiplier': 0.0, 'force_defined': False, 'deflection_force_offset': 0.0, 'deflection_force_multiplier': 1.0}, 'error': {'channel_id': 4}, 'capacitiveSensorHeight': {'channel_id': 5, 'encoder_type': 'signedinteger', 'encoder_offet_key': -2.835585312768e-06, 'encoder_multiplier_key': -5.63862e-15, 'base': 'absolute', 'base_defined': False, 'absolute_defined': False, 'capSensHeight_abs_offset': 0.0, 'capSensHeight_abs_mult': 1000000000.0, 'nominal_defined': True, 'capSensHeight_nom_offset': 6.5e-06, 'capSensHeight_nom_mult': 1.0}, 'measuredHeight': {'channel_id': 6, 'encoder_type': 'signedinteger', 'encoder_offet_key': -2.835585312768e-06, 'encoder_multiplier_key': -5.63862e-15, 'base': 'absolute', 'base_defined': False, 'absolute_defined': False, 'capSensHeight_abs_offset': 0.0, 'capSensHeight_abs_mult': 1000000000.0, 'nominal_defined': True, 'capSensHeight_nom_offset': 6.5e-06, 'capSensHeight_nom_mult': 1.0}, 'fast-scanner-height': {'channel_id': 7}, 'time': {'channel_id': 8}, 'seriesTime': {'channel_id': 9}}
#
# Recording_number_segment : 2
#
# curve_properties : {'0': {'0': {'time_stamp': '2018-11-22 17\\:54\\:05.107 +0100', 'num_points': 778, 'duration': 0.031120000000000005, 'channels': ['head-height', 'height', 'vDeflection', 'hDeflection', 'error', 'capacitiveSensorHeight', 'measuredHeight', 'fast-scanner-height', 'time', 'seriesTime'], 'baseline_measured': True, 'baseline': 0.31699047061322244, 'approach_id': '2018.11.22-15.33.50-00055', 'style': 'extend', 'setpoint': 3.894240223996698, 'z_start': 2000.0000000000002, 'z_end': 0.0, 'ramp_size': -2000.0000000000002, 'ramp_speed': -64267.35218508997}, '1': {'time_stamp': '2018-11-22 17\\:54\\:05.147 +0100', 'num_points': 1000, 'duration': 0.04000000000000001, 'channels': ['head-height', 'height', 'vDeflection', 'hDeflection', 'error', 'capacitiveSensorHeight', 'measuredHeight', 'fast-scanner-height', 'time', 'seriesTime'], 'baseline_measured': True, 'baseline': 0.31699047061322244, 'approach_id': '2018.11.22-15.33.50-00055', 'style': 'retract', 'z_start': 2000.0000000000002, 'z_end': 0.0, 'ramp_size': -2000.0000000000002, 'ramp_speed': -49999.99999999999}}, '1': {'0': {'time_stamp': '2018-11-22 17\\:54\\:05.187 +0100', 'num_points': 988, 'duration': 0.03952000000000001, 'channels': ['head-height', 'height', 'vDeflection', 'hDeflection', 'error', 'capacitiveSensorHeight', 'measuredHeight', 'fast-scanner-height', 'time', 'seriesTime'], 'baseline_measured': True, 'baseline': 0.31699047061322244, 'approach_id': '2018.11.22-15.33.50-00055', 'style': 'extend', 'setpoint': 3.894240223996698, 'z_start': 2000.0000000000002, 'z_end': 0.0, 'ramp_size': -2000.0000000000002, 'ramp_speed': -50607.2874493927}, '1': {'time_stamp': '2018-11-22 17\\:54\\:05.227 +0100', 'num_points': 1000, 'duration': 0.04000000000000001, 'channels': ['head-height', 'height', 'vDeflection', 'hDeflection', 'error', 'capacitiveSensorHeight', 'measuredHeight', 'fast-scanner-height', 'time', 'seriesTime'], 'baseline_measured': True, 'baseline': 0.31699047061322244, 'approach_id': '2018.11.22-15.33.50-00055', 'style': 'retract', 'z_start': 2000.0000000000002, 'z_end': 0.0, 'ramp_size': -2000.0000000000002, 'ramp_speed': -49999.99999999999}}, '10': {'0': {'time_stamp': '2018-11-22 17\\:54\\:05.908 +0100', 'num_points': 994, 'duration': 0.039760000000000004, 'channels': ['head-height', 'height', 'vDeflection', 'hDeflection', 'error', 'capacitiveSensorHeight', 'measuredHeight', 'fast-scanner-height', 'time', 'seriesTime'], 'baseline_measured': True, 'baseline': 0.31699047061322244, 'approach_id': '2018.11.22-15.33.50-00055', 'style': 'extend', 'setpoint': 3.894240223996698, 'z_start': 2000.0000000000002, 'z_end': 0.0, 'ramp_size': -2000.0000000000002, 'ramp_speed': -50301.810865191146}, '1': {'time_stamp': '2018-11-22 17\\:54\\:05.948 +0100', 'num_points': 1000, 'duration': 0.04000000000000001, 'channels': ['head-height', 'height', 'vDeflection', 'hDeflection', 'error', 'capacitiveSensorHeight', 'measuredHeight', 'fast-scanner-height', 'time', 'seriesTime'], 'baseline_measured': True, 'baseline': 0.31699047061322244, 'approach_id': '2018.11.22-15.33.50-00055', 'style': 'retract', 'z_start': 2000.0000000000002, 'z_end': 0.0, 'ramp_size': -2000.0000000000002, 'ramp_speed': -49999.99999999999}}, '100': {'0': {'time_stamp': '2018-11-22 17\\:54\\:14.596 +0100', 'num_points': 989, 'duration': 0.03956000000000001, 'channels': ['head-height', 'height', 'vDeflection', 'hDeflection', 'error', 'capacitiveSensorHeight', 'measuredHeight', 'fast-scanner-height', 'time', 'seriesTime'], 'baseline_measured': True, 'baseline': 0.2432005688157805, 'approach_id': '2018.11.22-15.33.50-00055', 'style': 'extend', 'setpoint': 3.894240223996698, 'z_start': 2000.0000000000002, 'z_end': 0.0, 'ramp_size': -2000.0000000000002, 'ramp_speed': -50556.1172901921}, '1': {'time_stamp': '2018-11-22 17\\:54\\:14.636 +0100', 'num_points': 1000, 'duration': 0.04000000000000001, 'channels': ['head-height', 'height', 'vDeflection', 'hDeflection', 'error', 'capacitiveSensorHeight', 'measuredHeight' ...
#
# found_vDeflection : True
#
# height_channel_key : measuredHeight

# %%
nowfnridf

# %%
# 5. Get force curve at index 0
FC = NANOSC_PFC_FILE.getcurve(0)

type(FC)
# Out:
# pyfmreader.utils.forcecurve.ForceCurve

# %%
help(FC.preprocess_force_curve)
# Out:
# Help on method preprocess_force_curve in module pyfmreader.utils.forcecurve:
#
# preprocess_force_curve(deflection_sens, height_channel_key, y0=None) method of pyfmreader.utils.forcecurve.ForceCurve instance
#     Computes Vertical Deflection in m and populates the vdeflection, zheight
#     and time properties for each segment in the force curve.
#
#     vDeflection(m) = (vDeflection(V) - baseline(V)) * deflection_sens(m/V)
#
#     if y0 is not None:
#         vDeflection(m) = (vDeflection(V) - y0(V)) * deflection_sens(m/V)
#
#             Parameters:
#                     deflection_sens (float): In m/V
#                     height_channel_key (str): Dictionary key to find height data in self.segment_formated_data.
#                     y0 (float): Manual offset for the vertical deflection, in Volts.
#
#             Returns: None

# %%
# 6. Preprocess curve with the deflection sens in the header
defl_sens = metadata['defl_sens_nmbyV'] / 1e09 # nm/V --> m/V
FC.preprocess_force_curve(defl_sens, metadata['height_channel_key'])
plt.figure(figsize=(10,5))
for segid, segment in FC.get_segments():
    plt.plot(-1*segment.zheight, segment.vdeflection, label=f'Segment: {segid}')
plt.xlabel('zheight [m]')
plt.ylabel('vdeflection [m]')
plt.legend()
plt.show()

# %%
# 7. Get Force vs Indentation curve
poc = [0.5 * 1e-8, 0.0] # in nm
spring_k = metadata['spring_const_Nbym']
FC.get_force_vs_indentation(poc, spring_k)
plt.figure(figsize=(10,5))
for segid, segment in FC.get_segments():
    plt.plot(segment.indentation, segment.force, label=f'Segment: {segid}')
plt.axhline(y=0, color='k', linestyle='--')
plt.axvline(x=0, color='k', linestyle='--')
plt.xlabel('Indentation [m]')
plt.ylabel('Force [N]')
plt.legend()
plt.show()

# %%
# 8. Get segment 0
FC_segments = FC.get_segments()
_, segment_0 = FC_segments[0]
type(segment_0)
# Out:
# pyfmreader.utils.segment.Segment

# %%
# 9. Plot only segment 0
plt.figure(figsize=(10,5))
plt.plot(segment_0.zheight, segment_0.vdeflection, label=f'Segment: 0')
plt.xlabel('zheight [nm]')
plt.ylabel('vdeflection [nm]')
plt.legend()
plt.show()

# %%
# 9. Get force vs indentation for segment 0
plt.figure(figsize=(10,5))
plt.plot(segment_0.indentation, segment_0.force, label=f'Segment: 0')
plt.xlabel('zheight [nm]')
plt.ylabel('vdeflection [nm]')
plt.legend()
plt.show()
